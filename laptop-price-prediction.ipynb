# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df['Company'].value_counts().sum()
# Out:
# 1303

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_copy.iloc[:,1:]
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_copy['Price'] = df_copy['Price'].astype(int)

# %%
df_copy.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378
# ...

# %%
df_copy.iloc[:,1:]
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
#Remove mixed values from RAM
df_copy['Ram_GB'] = df_copy['Ram'].str.extract('(\d+)')

# %%
df_copy
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_copy.drop('Ram',inplace = True,axis = 1)

# %%
df_copy.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Weight   Price Ram_GB
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378      8
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895      8
# ...

# %%
#remove mixed values from weight
df_copy['Weight_Kg'] = df_copy['Weight'].str.extract('(\d+)')

# %%
df_copy.sample(5)
# Out:
#       Unnamed: 0  Company   TypeName  Inches  \
# 339          339     Dell   Notebook    15.6
# 1000        1000     Acer     Gaming    15.6
# 996          996       HP  Ultrabook    13.3
# 1110        1110       HP   Notebook    13.3
# 648          648  Toshiba   Notebook    13.3
#
#                                ScreenResolution                          Cpu  \
# 339                           Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# 1000                IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 996   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 1110           Quad HD+ / Touchscreen 3200x1800     Intel Core M 6Y54 1.1GHz
# 648                           Full HD 1920x1080   Intel Core i5 6200U 2.3GHz
#
#                     Memory                      Gpu       OpSys  Weight  \
# 339              256GB SSD     Nvidia GeForce 940MX  Windows 10     2kg
# 1000  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10   2.7kg
# ...

# %%
df_copy['Weight'].unique()
# Out:
# array(['1.37kg', '1.34kg', '1.86kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg',
#        '1.6kg', '2.2kg', '0.92kg', '1.22kg', '0.98kg', '2.5kg', '1.62kg',
#        '1.91kg', '2.3kg', '1.35kg', '1.88kg', '1.89kg', '1.65kg',
#        '2.71kg', '1.2kg', '1.44kg', '2.8kg', '2kg', '2.65kg', '2.77kg',
#        '3.2kg', '0.69kg', '1.49kg', '2.4kg', '2.13kg', '2.43kg', '1.7kg',
#        '1.4kg', '1.8kg', '1.9kg', '3kg', '1.252kg', '2.7kg', '2.02kg',
#        '1.63kg', '1.96kg', '1.21kg', '2.45kg', '1.25kg', '1.5kg',
#        '2.62kg', '1.38kg', '1.58kg', '1.85kg', '1.23kg', '1.26kg',
#        '2.16kg', '2.36kg', '2.05kg', '1.32kg', '1.75kg', '0.97kg',
#        '2.9kg', '2.56kg', '1.48kg', '1.74kg', '1.1kg', '1.56kg', '2.03kg',
#        '1.05kg', '4.4kg', '1.90kg', '1.29kg', '2.0kg', '1.95kg', '2.06kg',
#        '1.12kg', '1.42kg', '3.49kg', '3.35kg', '2.23kg', '4.42kg',
#        '2.69kg', '2.37kg', '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg',
# ...

# %%
df_copy.drop('Weight_Kg',inplace = True,axis = 1)

# %%
df_copy.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Weight   Price Ram_GB
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378      8
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895      8
# ...

# %%
df_copy['Weight_Kg'] = df_copy['Weight'].str.findall(r"[-+]?\d*\.\d+|\d+").apply(lambda x: float(x[0]) if x else None)

# %%
df_copy.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Weight   Price Ram_GB  Weight_Kg
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378      8       1.37
# ...

# %%
df_copy.drop('Weight' ,axis = True ,inplace = True)

# %%
df_copy.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price Ram_GB  Weight_Kg
# 0  Intel Iris Plus Graphics 640  macOS   71378      8       1.37
# ...

# %%
df_copy.iloc[:,1:12]
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_copy['Price'].value_counts().sum()
# Out:
# 1303

# %%
#no null values present in columns
df_copy.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Price               0
# Ram_GB              0
# Weight_Kg           0
# dtype: int64

# %%
#duplicate values
df_copy.duplicated().sum()
# Out:
# 0

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Price             1303 non-null   int32
#  10  Ram_GB            1303 non-null   object
#  11  Weight_Kg         1303 non-null   float64
# dtypes: float64(2), int32(1), int64(1), object(8)
# memory usage: 117.2+ KB

# %%
#now perform some uni and univariate analysis

# %%
df_copy['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
sns.countplot(df_copy['Company'].head(30))
# Out:
# C:\Users\The One\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Company', ylabel='count'>

# %%
df['Company'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Company'>

# %%
sns.countplot(df_copy['TypeName'].sample(10))
# Out:
# C:\Users\The One\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TypeName', ylabel='count'>

# %%
df_copy['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
df_copy.describe()
# Out:
#        Unnamed: 0       Inches          Price    Weight_Kg
# count  1303.00000  1303.000000    1303.000000  1303.000000
# mean    651.00000    15.017191   59869.539524     2.038734
# std     376.28801     1.426304   37243.198508     0.665475
# min       0.00000    10.100000    9270.000000     0.690000
# 25%     325.50000    14.000000   31914.000000     1.500000
# 50%     651.00000    15.600000   52054.000000     2.040000
# 75%     976.50000    15.600000   79274.000000     2.300000
# max    1302.00000    18.400000  324954.000000     4.700000

# %%
df_copy.corr()['Price']
# Out:
# Unnamed: 0    0.067985
# Inches        0.068196
# Price         1.000000
# Weight_Kg     0.210370
# Name: Price, dtype: float64

# %%
df_copy
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df_copy.drop('Unnamed: 0' ,inplace = True ,axis = 1)

# %%
df_copy
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
sns.histplot(df_copy['Price'] )
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df_copy['Company'] ,y = df_copy['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = df_copy['Inches'] ,y = df_copy['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
 df['Inches'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(df_copy['Inches'],df_copy['Price'])
# Out:
# C:\Users\The One\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df_copy.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price Ram_GB  Weight_Kg
# 0  Intel Iris Plus Graphics 640  macOS   71378      8       1.37
# 1        Intel HD Graphics 6000  macOS   47895      8       1.34
# 2         Intel HD Graphics 620  No OS   30636      8       1.86
# ...

# %%
#use feature engineering to select and extract information from multiple columns
df_copy['Ips'] = df_copy['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df_copy['TouchScreen'] = df_copy['ScreenResolution'].apply(lambda x:1 if 'TouchScreen' in x else 0)

# %%
df_copy.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price Ram_GB  Weight_Kg  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   71378      8       1.37    1
# 1        Intel HD Graphics 6000  macOS   47895      8       1.34    0
# ...

# %%
#how to extract columns from 
df_copy[['X_res', 'Y_res']] = df_copy['ScreenResolution'].str.extract(r'(\d+)x(\d+)')

# %%
df_copy
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Memory            1303 non-null   object
#  6   Gpu               1303 non-null   object
#  7   OpSys             1303 non-null   object
#  8   Price             1303 non-null   int32
#  9   Ram_GB            1303 non-null   object
#  10  Weight_Kg         1303 non-null   float64
#  11  Ips               1303 non-null   int64
#  12  TouchScreen       1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float64(2), int32(1), int64(2), object(10)
# ...

# %%
df_copy['X_res'] = df_copy['X_res'].astype('int32')
df_copy['Y_res'] = df_copy['Y_res'].astype('int32')

# %%
df_copy.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price Ram_GB  Weight_Kg  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   71378      8       1.37    1
# 1        Intel HD Graphics 6000  macOS   47895      8       1.34    0
# ...

# %%
df_copy.corr()['Price']
# Out:
# Inches         0.068196
# Price          1.000000
# Weight_Kg      0.210370
# Ips            0.252207
# TouchScreen         NaN
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df_copy.drop('TouchScreen' , axis = 1 ,inplace = True)

# %%
df_copy
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_copy['Touchscreen'] = df_copy['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df_copy.sample(5)
# Out:
#       Company   TypeName  Inches             ScreenResolution  \
# 356    Lenovo   Notebook    15.6                     1366x768
# 390      Asus     Gaming    17.3            Full HD 1920x1080
# 784    Lenovo  Ultrabook    14.0            Full HD 1920x1080
# 198        HP     Gaming    17.3  IPS Panel Full HD 1920x1080
# 1118  Toshiba  Ultrabook    13.3            Full HD 1920x1080
#
#                                        Cpu                Memory  \
# 356   Intel Celeron Dual Core N3350 1.1GHz               1TB HDD
# 390            Intel Core i7 7700HQ 2.8GHz               1TB HDD
# 784             Intel Core i7 7500U 2.7GHz             512GB SSD
# 198            Intel Core i7 7700HQ 2.8GHz  256GB SSD +  1TB HDD
# 1118            Intel Core i7 7500U 2.7GHz             512GB SSD
#
#                           Gpu       OpSys   Price Ram_GB  Weight_Kg  Ips  \
# 356     Intel HD Graphics 500       No OS   17155      4       2.20    0
# ...

# %%
df_copy['Touchscreen'].value_counts()
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
df_copy.corr()['Price']
# Out:
# Inches         0.068196
# Price          1.000000
# Weight_Kg      0.210370
# Ips            0.252207
# X_res          0.556529
# Y_res          0.552809
# Touchscreen    0.191226
# Name: Price, dtype: float64

# %%
df_copy['Ram_GB'] = df_copy['Ram_GB'].astype('int32')

# %%
df_copy['ppi'] = (((df_copy['X_res']**2) + (df_copy['Y_res']**2))**0.5/df_copy['Inches']).astype('float')

# %%
df_copy.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price  Ram_GB  Weight_Kg  Ips  X_res  \
# 0  Intel Iris Plus Graphics 640  macOS   71378       8       1.37    1   2560
# 1        Intel HD Graphics 6000  macOS   47895       8       1.34    0   1440
# ...

# %%
df_copy.drop('X_res',axis = 1 ,inplace = True)
df_copy.drop('Y_res',axis = 1 ,inplace = True)
df_copy.drop('Inches',axis = 1 ,inplace = True)

# %%
df_copy.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price  Ram_GB  Weight_Kg  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   71378       8       1.37    1
# 1        Intel HD Graphics 6000  macOS   47895       8       1.34    0
# 2         Intel HD Graphics 620  No OS   30636       8       1.86    0
# ...

# %%
df_copy['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df_copy['Cpu Name'] = df_copy['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df_copy['Cpu brand'] = df_copy['Cpu Name'].apply(fetch_processor)

# %%
df_copy.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys   Price  Ram_GB  Weight_Kg  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   71378       8       1.37    1
# 1        Intel HD Graphics 6000  macOS   47895       8       1.34    0
# 2         Intel HD Graphics 620  No OS   30636       8       1.86    0
# ...

# %%
df_copy['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df_copy['Cpu brand'],y=df_copy['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df_copy['Ram_GB'],y=df_copy['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df_copy['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df = df_copy

# %%
df
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df = df_copy

# %%
df
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]


df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],axis = 1, inplace=True)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\2381945694.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\2381945694.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu             Memory  \
# 0        Intel Core i5 2.3GHz            128 SSD
# 1        Intel Core i5 1.8GHz  128 Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256 SSD
# 3        Intel Core i7 2.7GHz            512 SSD
# 4        Intel Core i5 3.1GHz            256 SSD
#
#                             Gpu  OpSys   Price  Ram_GB  Weight_Kg  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS   71378       8       1.37    1
# 1        Intel HD Graphics 6000  macOS   47895       8       1.34    0
# 2         Intel HD Graphics 620  No OS   30636       8       1.86    0
# ...

# %%
df.drop(columns=['Memory'],axis = 1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu                           Gpu  OpSys   Price  \
# 0        Intel Core i5 2.3GHz  Intel Iris Plus Graphics 640  macOS   71378
# 1        Intel Core i5 1.8GHz        Intel HD Graphics 6000  macOS   47895
# 2  Intel Core i5 7200U 2.5GHz         Intel HD Graphics 620  No OS   30636
# 3        Intel Core i7 2.7GHz            AMD Radeon Pro 455  macOS  135195
# 4        Intel Core i5 3.1GHz  Intel Iris Plus Graphics 650  macOS   96095
#
#    Ram_GB  Weight_Kg  Ips  Touchscreen         ppi       Cpu Name  \
# 0       8       1.37    1            0  226.983005  Intel Core i5
# ...

# %%
df.corr()['Price']
# Out:
# Price            1.000000
# Ram_GB           0.743007
# Weight_Kg        0.210370
# Ips              0.252207
# Touchscreen      0.191226
# ppi              0.473487
# HDD             -0.096442
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],axis = 1 ,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu                           Gpu  OpSys   Price  \
# 0        Intel Core i5 2.3GHz  Intel Iris Plus Graphics 640  macOS   71378
# 1        Intel Core i5 1.8GHz        Intel HD Graphics 6000  macOS   47895
# 2  Intel Core i5 7200U 2.5GHz         Intel HD Graphics 620  No OS   30636
# 3        Intel Core i7 2.7GHz            AMD Radeon Pro 455  macOS  135195
# 4        Intel Core i5 3.1GHz  Intel Iris Plus Graphics 650  macOS   96095
#
#    Ram_GB  Weight_Kg  Ips  Touchscreen         ppi       Cpu Name  \
# 0       8       1.37    1            0  226.983005  Intel Core i5
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu                           Gpu  OpSys   Price  \
# 0        Intel Core i5 2.3GHz  Intel Iris Plus Graphics 640  macOS   71378
# 1        Intel Core i5 1.8GHz        Intel HD Graphics 6000  macOS   47895
# 2  Intel Core i5 7200U 2.5GHz         Intel HD Graphics 620  No OS   30636
# 3        Intel Core i7 2.7GHz            AMD Radeon Pro 455  macOS  135195
# 4        Intel Core i5 3.1GHz  Intel Iris Plus Graphics 650  macOS   96095
#
#    Ram_GB  Weight_Kg  Ips  Touchscreen         ppi       Cpu Name  \
# 0       8       1.37    1            0  226.983005  Intel Core i5
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df['Gpu brand'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
sns.barplot(x=df['Price'] ,y=df['Gpu brand'] ,estimator =np.median)
plt.xticks(rotation='horizontal')
plt.show()

# %%
df.drop(columns=['Gpu'],axis = 1, inplace=True)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\3203228486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],axis = 1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  OpSys   Price  Ram_GB  Weight_Kg  Ips  \
# 0        Intel Core i5 2.3GHz  macOS   71378       8       1.37    1
# 1        Intel Core i5 1.8GHz  macOS   47895       8       1.34    0
# 2  Intel Core i5 7200U 2.5GHz  No OS   30636       8       1.86    0
# 3        Intel Core i7 2.7GHz  macOS  135195      16       1.83    1
# 4        Intel Core i5 3.1GHz  macOS   96095       8       1.37    1
#
#    Touchscreen         ppi       Cpu Name      Cpu brand  HDD  SSD Gpu brand
# 0            0  226.983005  Intel Core i5  Intel Core i5    0  128     Intel
# ...

# %%
df.drop(columns=['Cpu Name'],axis = 1, inplace=True)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\3639256074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Cpu Name'],axis = 1, inplace=True)

# %%
df.shape
# Out:
# (1302, 15)

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\3648919379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  OpSys   Price  Ram_GB  Weight_Kg  Ips  \
# 0        Intel Core i5 2.3GHz  macOS   71378       8       1.37    1
# 1        Intel Core i5 1.8GHz  macOS   47895       8       1.34    0
# 2  Intel Core i5 7200U 2.5GHz  No OS   30636       8       1.86    0
# 3        Intel Core i7 2.7GHz  macOS  135195      16       1.83    1
# 4        Intel Core i5 3.1GHz  macOS   96095       8       1.37    1
#
#    Touchscreen         ppi      Cpu brand  HDD  SSD Gpu brand  \
# 0            0  226.983005  Intel Core i5    0  128     Intel
# 1            0  127.677940  Intel Core i5    0    0     Intel
# ...

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\3105339334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Price  Ram_GB  Weight_Kg  Ips  Touchscreen  \
# 0        Intel Core i5 2.3GHz   71378       8       1.37    1            0
# 1        Intel Core i5 1.8GHz   47895       8       1.34    0            0
# 2  Intel Core i5 7200U 2.5GHz   30636       8       1.86    0            0
# 3        Intel Core i7 2.7GHz  135195      16       1.83    1            0
# 4        Intel Core i5 3.1GHz   96095       8       1.37    1            0
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# ...

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop('ScreenResolution' ,axis = 1 , inplace = True)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\468849309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('ScreenResolution' ,axis = 1 , inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu   Price  Ram_GB  Weight_Kg  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   71378       8       1.37
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   47895       8       1.34
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   30636       8       1.86
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  135195      16       1.83
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   96095       8       1.37
#
#    Ips  Touchscreen         ppi      Cpu brand  HDD  SSD Gpu brand  \
# 0    1            0  226.983005  Intel Core i5    0  128     Intel
# 1    0            0  127.677940  Intel Core i5    0    0     Intel
# 2    0            0  141.211998  Intel Core i5    0  256     Intel
# 3    1            0  220.534624  Intel Core i7    0  512       AMD
# 4    1            0  226.983005  Intel Core i5    0  256     Intel
#
#                    os
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# ...

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\The One\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\The One\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram_GB  Weight_Kg  Ips  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz       8       1.37    1
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz       8       1.34    0
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz       8       1.86    0
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz      16       1.83    1
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz       8       1.37    1
#
#    Touchscreen         ppi      Cpu brand  HDD  SSD Gpu brand  \
# 0            0  226.983005  Intel Core i5    0  128     Intel
# 1            0  127.677940  Intel Core i5    0    0     Intel
# 2            0  141.211998  Intel Core i5    0  256     Intel
# 3            0  220.534624  Intel Core i7    0  512       AMD
# 4            0  226.983005  Intel Core i5    0  256     Intel
#
#                    os
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# 3                 Mac
# 4                 Mac

# %%
df['Price'] = df_copy['Price']
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\2480996957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df_copy['Price']

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram_GB  Weight_Kg  Ips  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz       8       1.37    1
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz       8       1.34    0
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz       8       1.86    0
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz      16       1.83    1
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz       8       1.37    1
#
#    Touchscreen         ppi      Cpu brand  HDD  SSD Gpu brand  \
# 0            0  226.983005  Intel Core i5    0  128     Intel
# 1            0  127.677940  Intel Core i5    0    0     Intel
# 2            0  141.211998  Intel Core i5    0  256     Intel
# 3            0  220.534624  Intel Core i7    0  512       AMD
# 4            0  226.983005  Intel Core i5    0  256     Intel
#
#                    os   Price
# 0                 Mac   71378
# 1                 Mac   47895
# 2  Others/No OS/Linux   30636
# ...

# %%
df.drop(columns=['Cpu'] ,inplace = True)
# Out:
# C:\Users\The One\AppData\Local\Temp\ipykernel_7564\2218224830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Cpu'] ,inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram_GB  Weight_Kg  Ips  Touchscreen         ppi  \
# 0   Apple  Ultrabook       8       1.37    1            0  226.983005
# 1   Apple  Ultrabook       8       1.34    0            0  127.677940
# 2      HP   Notebook       8       1.86    0            0  141.211998
# 3   Apple  Ultrabook      16       1.83    1            0  220.534624
# 4   Apple  Ultrabook       8       1.37    1            0  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os   Price
# 0  Intel Core i5    0  128     Intel                 Mac   71378
# 1  Intel Core i5    0    0     Intel                 Mac   47895
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux   30636
# 3  Intel Core i7    0  512       AMD                 Mac  135195
# 4  Intel Core i5    0  256     Intel                 Mac   96095

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
#model selection
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %%
X_train
# Out:
#      Company   TypeName  Ram_GB  Weight_Kg  Ips  Touchscreen         ppi  \
# 91      Acer   Notebook       8       2.20    0            0  141.211998
# 863   Lenovo     Gaming       8       2.50    1            0  141.211998
# 552     Dell     Gaming      16       4.42    1            0  127.335675
# 967       HP   Notebook       4       2.04    0            0  141.211998
# 365       HP   Notebook       8       2.04    0            0  100.454670
# ...      ...        ...     ...        ...  ...          ...         ...
# 466     Acer   Notebook       4       2.20    0            0  100.454670
# 299     Asus  Ultrabook      16       1.63    0            0  141.211998
# 493     Acer   Notebook       8       2.20    0            0  100.454670
# 527   Lenovo   Notebook       8       2.20    0            0  100.454670
# 1193   Apple  Ultrabook       8       0.92    1            0  226.415547
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
#display pipeline
from sklearn import set_config
set_config(display='diagram')

# %%
#Random Forest 
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8672340096932021
# MAE 0.16391528027943797

# %%
#Exporting the model 
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import sklearn

# Print the scikit-learn version
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Scikit-learn version: 1.0.2
